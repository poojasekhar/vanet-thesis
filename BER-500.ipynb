# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel("BER.xlsx")

df = df.reset_index(drop=True)
df
# Out:
#    BACVT8_2     BACVT  BACVT5_5       2mW      10mW      20mW    QBTPCC
# 0  0.018687  0.020339  0.021309  0.009826  0.024941  0.024586  0.004969

# %%
poo = sns.barplot(data=df,color=None, palette='rocket_r')
plt.xlabel("Algorithm")
plt.ylabel("BER")
fig = poo.get_figure()
fig.savefig("output.png")
