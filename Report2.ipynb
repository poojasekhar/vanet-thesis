# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel("Book3.xlsx")

df = df.reset_index(drop=True)
df
# Out:
#    BACVT8_2    BACVT   BACVT_5     QBACC
# 0  0.002053  0.00181  0.001939  0.001746

# %%
poo = sns.barplot(data=df,color=None, palette='rocket_r')
plt.xlabel("Power")
plt.ylabel("BER")
fig = poo.get_figure()
fig.savefig("output.png")
